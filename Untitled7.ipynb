# %% [markdown]
# <a href="https://colab.research.google.com/github/StevenDreamer1/DATA-MAINING/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %%
data, labels = make_blobs(n_samples=300, n_features=2, centers=4, random_state=42)
df = pd.DataFrame(data)
df.head()
# Out:
#            0         1
# 0  -9.297689  6.473679
# 1  -9.698741  6.938967
# 2  -1.686653  7.793442
# 3  -7.097308 -5.781333
# 4 -10.876452  6.315437

# %%
X, _ = make_blobs(n_samples=300, centers=3, cluster_std=0.60, random_state=0)
X_train, X_test = train_test_split(X, test_size=0.2, random_state=42)
kmeans = KMeans(n_clusters=5, random_state=42)
kmeans.fit(X_train)
y_train_pred = kmeans.predict(X_train)
y_test_pred = kmeans.predict(X_test)
train_silhouette = silhouette_score(X_train, y_train_pred)
test_silhouette = silhouette_score(X_test, y_test_pred)
print(f"Silhouette score on training set: {train_silhouette:.2f}")
print(f"Silhouette score on test set: {test_silhouette:.2f}")
# Out:
# Silhouette score on training set: 0.41
# Silhouette score on test set: 0.40

# %%
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train_pred, s=50, cmap='viridis',label='Training Data')
plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test_pred, s=50, cmap='plasma',label='Testing Data',alpha=0.5)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='red',label='Centroids')
plt.title('K-means Clustering')
plt.legend()
plt.show()
